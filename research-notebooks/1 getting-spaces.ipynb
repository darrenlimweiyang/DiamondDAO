# %%
import json
import requests
import boto3
import pandas as pd
from datetime import datetime
from pprint import pprint
import seaborn as sns
import os.path

# %%
query = '''
query {
  spaces(
    first: 3000,
    skip: 0,
    orderBy: "created",
    orderDirection: asc
  ) {
    id
    name
    about
    network
    symbol
    strategies {
      name
      params
    }
    admins
    members
    filters {
      minScore
      onlyMembers
    }
    plugins
  }
}
'''
response = requests.post(
    'https://hub.snapshot.org/graphql',
    '',
    json={"query": query}
    )

# %% [markdown]
# # Function to clean spaces into df

# %%
def clean_spaces_to_df(response_obj):
    list_of_spaces = pd.DataFrame(response_obj.json()['data']['spaces'])
    return list_of_spaces


def adding_no_of_members_to_df(spaces_df):
    spaces_df['no_of_members'] = spaces_df['members'].apply(lambda x: len(x))
    return spaces_df

# %%
space_df = clean_spaces_to_df(response)

space_df = adding_no_of_members_to_df(space_df)

# %%
space_df.sort_values(by='no_of_members',
                    ascending=False)
# Out:
#                       id                 name  \
# 568      dolphincoin.eth         Dolphin club
# 930           htmoon.eth               HTMoon
# 85       CryptoKaiju.eth                KAIJU
# 1136      compusophy.eth           compusophy
# 1382             mcv.eth  MetaCartel Ventures
# ...                  ...                  ...
# 1302           ikram.eth                Ikram
# 1299        betswirl.eth             BetSwirl
# 324   pootogetherbsc.eth          PooTogether
# 1295          fuschu.eth             REP-Test
# 1109      mariapaula.eth         Maria Paula
#
#                                                   about network      symbol  \
# 568                                            一场伟大社区实验      56         DOC
# 930                                                         128      HTMoon
# 85                                                            1       KAIJU
# 1136                              part reflecting whole       1  COLLECTIVE
# 1382                                                          1         MCV
# ...                                                 ...     ...         ...
# 1302                                                         42        NIOX
# 1299  BetSwirl is a community & fair driven gambling...     137        BETS
# 324                                                          56         POO
# 1295                                                          4         REP
# 1109                                               Test       5         ETH
#
#                                              strategies  \
# 568   [{'name': 'erc20-balance-of', 'params': {'symb...
# 930   [{'name': 'erc20-balance-of', 'params': {'symb...
# 85    [{'name': 'erc20-balance-of', 'params': {'symb...
# 1136  [{'name': 'erc1155-balance-of', 'params': {'sy...
# 1382  [{'name': 'moloch-all', 'params': {'symbol': '...
# ...                                                 ...
# 1302  [{'name': 'erc20-balance-of', 'params': {'symb...
# 1299  [{'name': 'erc20-balance-of', 'params': {'symb...
# 324   [{'name': 'erc20-balance-of', 'params': {'symb...
# 1295  [{'name': 'erc20-balance-of', 'params': {'symb...
# 1109  [{'name': 'ticket', 'params': {'symbol': 'DAI'...
#
#                                                  admins  \
# 568                                                  []
# 930        [0xce09B446636eCAf4D99846312A405E0f21a34443]
# 85                                                   []
# 1136       [0xDcAa03A2Ff649B233946E6d9960f98D67fAf802B]
# 1382                                                 []
# ...                                                 ...
# 1302  [0xd0b4FA58577Db029a6e709028192ab423d1DCaee, 0...
# 1299       [0x2C305888a456E7004663bc12A74395E637eABCBc]
# 324                                                  []
# 1295                                                 []
# 1109                                                 []
#
#                                                 members  \
# 568   [0x68efc4952425a0f432761c9538b02b10ddb1635b, 0...
# 930   [0xce09B446636eCAf4D99846312A405E0f21a34443, 0...
# 85    [HolderAddress, 0xacf6d9343024c16a81725d0e509c...
# 1136  [0xDcAa03A2Ff649B233946E6d9960f98D67fAf802B, 0...
# 1382  [0x512e07a093aaa20ba288392eadf03838c7a4e522, 0...
# ...                                                 ...
# 1302                                                 []
# 1299                                                 []
# 324                                                  []
# 1295                                                 []
# 1109                                                 []
#
#                                                filters plugins  no_of_members
# 568     {'minScore': 5000000000, 'onlyMembers': False}      {}           9310
# 930   {'minScore': 1000000000000, 'onlyMembers': True}      {}           2000
# 85              {'minScore': 10, 'onlyMembers': False}      {}           1167
# 1136             {'minScore': 0, 'onlyMembers': False}      {}            215
# 1382              {'minScore': 0, 'onlyMembers': True}      {}            188
# ...                                                ...     ...            ...
# 1302             {'minScore': 0, 'onlyMembers': False}      {}              0
# 1299              {'minScore': 0, 'onlyMembers': True}      {}              0
# 324              {'minScore': 0, 'onlyMembers': False}      {}              0
# 1295             {'minScore': 0, 'onlyMembers': False}      {}              0
# 1109             {'minScore': 0, 'onlyMembers': False}      {}              0
#
# [2219 rows x 11 columns]

# %% [markdown]
# # Function to download csv data

# %%
def takes_csv_spaces_and_downloads_it(df):
    today_date = datetime.today().date().strftime("%Y-%m-%d")
    file_name = "datasets/spaces/{}_spaces_v0.csv".format(today_date)
    for i in range(10):
        if (os.path.isfile(file_name)):
            file_name = file_name.replace("v"+str(i), "v"+str(i+1))
    df.to_csv(file_name)

# %%
takes_csv_spaces_and_downloads_it(space_df)

# %%
space_df
# Out:
#                        id               name  \
# 0          bonustrack.eth                 Hi
# 1              fabien.eth             Fabien
# 2                ichi.eth          ichi.farm
# 3        loyalfinance.eth      loyal.finance
# 4             damflux.eth               FLUX
# ...                   ...                ...
# 2214      fevrhodlers.eth  FEVR Hodlers Club
# 2215      slimysnails.eth    slimeDAO Voting
# 2216  anglegovernance.eth     Angle Protocol
# 2217      hyaliko-dao.eth        hyaliko dao
# 2218   midsummerparty.eth          Midsummer
#
#                                                   about network     symbol  \
# 0                                                             1     TICKET
# 1                                 This is a test space!       4          $
# 2                                                             1  ICHIPOWAH
# 3                                                             1       rLYL
# 4                                                             1       FLUX
# ...                                                 ...     ...        ...
# 2214                 RealFevr - Everlasting NFT Moments      56       FEVR
# 2215  Voting on the future of Slimy Snails, one deci...       1      SNAIL
# 2216  The goal of the DAO is to collectively manage ...       1      ANGLE
# 2217                                                          1       HLKO
# 2218            storytelling production + distribution        1       REEL
#
#                                              strategies  \
# 0     [{'name': 'ticket', 'params': {'symbol': 'TICK...
# 1     [{'name': 'ticket', 'params': {'value': 100, '...
# 2     [{'name': 'erc20-balance-of', 'params': {'symb...
# 3     [{'name': 'erc20-balance-of', 'params': {'symb...
# 4     [{'name': 'erc20-balance-of', 'params': {'symb...
# ...                                                 ...
# 2214  [{'name': 'erc20-balance-of', 'params': {'symb...
# 2215  [{'name': 'erc721', 'params': {'symbol': 'SNAI...
# 2216  [{'name': 'erc20-balance-of', 'params': {'symb...
# 2217  [{'name': 'erc721-with-multiplier', 'params': ...
# 2218  [{'name': 'erc20-balance-of', 'params': {'symb...
#
#                                                  admins  \
# 0                                                    []
# 1     [0xeF8305E140ac520225DAf050e2f71d5fBcC543e7, 0...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2214       [0xA9E3240E5873E5812EC1C682729DC30B95E3242e]
# 2215       [0x5a3e0bb30423fa1b7601a06c5f88b862f7d77c71]
# 2216  [0xfdA462548Ce04282f4B6D6619823a7C64Fdc0185, 0...
# 2217       [0x8D94ae183D36c2e0931555fAbAc20589ccF0A631]
# 2218  [0x2ee8D80de1c389f1254e94bc44D2d1Bc391eD402, 0...
#
#                                                 members  \
# 0     [0x24A12Fa313F57aF541d447c594072A992c605DCf, 0...
# 1          [0xeF8305E140ac520225DAf050e2f71d5fBcC543e7]
# 2          [0x873902a3c0731EcC1F2075435FE035ACCeEd5459]
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2214  [0xA9E3240E5873E5812EC1C682729DC30B95E3242e, 0...
# 2215       [0x5a3e0bb30423fa1b7601a06c5f88b862f7d77c71]
# 2216  [0xfdA462548Ce04282f4B6D6619823a7C64Fdc0185, 0...
# 2217       [0x8D94ae183D36c2e0931555fAbAc20589ccF0A631]
# 2218  [0x2ee8D80de1c389f1254e94bc44D2d1Bc391eD402, 0...
#
#                                        filters  \
# 0        {'minScore': 0, 'onlyMembers': False}
# 1        {'minScore': 1, 'onlyMembers': False}
# 2        {'minScore': 0, 'onlyMembers': False}
# 3        {'minScore': 0, 'onlyMembers': False}
# 4        {'minScore': 0, 'onlyMembers': False}
# ...                                        ...
# 2214      {'minScore': 0, 'onlyMembers': True}
# 2215     {'minScore': 1, 'onlyMembers': False}
# 2216  {'minScore': 1000, 'onlyMembers': False}
# 2217     {'minScore': 9, 'onlyMembers': False}
# 2218     {'minScore': 0, 'onlyMembers': False}
#
#                                                 plugins  no_of_members
# 0     {'safeSnap': {'address': '0xeF8305E140ac520225...              9
# 1     {'aragon': {'id': 'bitconnect'}, 'safeSnap': {...              1
# 2                                                    {}              1
# 3                                                    {}              0
# 4                                                    {}              0
# ...                                                 ...            ...
# 2214                                                 {}              2
# 2215                                                 {}              1
# 2216                                                 {}              5
# 2217                                                 {}              1
# 2218                                                 {}              2
#
# [2219 rows x 11 columns]
